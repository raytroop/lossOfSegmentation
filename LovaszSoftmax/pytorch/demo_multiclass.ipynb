# %% [markdown]
# # Multiclass segmentation with the Lovász-Softmax
# ## PyTorch version

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from __future__ import division, print_function

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import torch
from torch.autograd import Variable
import torch.nn.functional as F
from torch.optim import Adam
from torch import nn

# %%
import lovasz_losses as L

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from tqdm import tqdm_notebook as tqdm

# %%
# add parent path to pythonpath to import demo_utils
import sys
sys.path.append('../demo_helpers')
from demo_utils import pil, pil_grid, dummy_triangles

# %%
from collections import OrderedDict as OD

# %%
CUDA = True

# %%
def cuda(x):
    if CUDA:
        return x.cuda()
    else:
        return x

# %% [markdown]
# ## Batch of 5 random images with classes [0, 1, 2] and void (255)

# %% [markdown]
# ### Labels

# %%
np.random.seed(18)
C = 3
B = 5
H = 200
labels_ = [dummy_triangles(H, [0, 255, 1, 2]) for b in range(B)]
labels = torch.stack(list(map(torch.from_numpy, map(np.array, labels_)))).long()
pil_grid(labels_, 5, margin=1)
# Out:
# <PIL.Image.Image image mode=RGB size=1005x205 at 0x7F8EF55CB080>

# %% [markdown]
# ### Features

# %%
np.random.seed(57)
B, H, W = labels.size()
labels_ = labels.clone()
labels_[labels_ == 255] = labels_[labels_ == 255].random_(C) # random feats for void
labels_1hot = torch.zeros(B, C, H, W)
labels_1hot.scatter_(1, labels_.unsqueeze(1), 1);

# %%
feats = labels_1hot.clone().float()
feats += feats.new(feats.size()).normal_(0, 2) # additive gaussian noise

# %%
labels = cuda(labels)
feats = Variable(cuda(feats))

# %% [markdown]
# ## Model

# %% [markdown]
# ### definition

# %%
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.conv = nn.Conv2d(C, C, 3, padding=1)
        
    def forward(self, x):
        return x + self.conv(x)

# %%
m = Model()
init_state_dict = OD([(n, p.clone()) for (n, p) in m.state_dict().items()])

# %%
m = cuda(m)

# %% [markdown]
# ### Initial prediction

# %%
with torch.no_grad():
    _, preds = m(feats).data.max(1)
    print("Initial batch-IoUs:", L.iou(preds.cpu().numpy(), labels.cpu().numpy(), C, ignore=255, per_image=False))
    print("Initial mIoU:", np.mean(L.iou(preds.cpu().numpy(), labels.cpu().numpy(), C, ignore=255, per_image=False)))
# Out:
# Initial batch-IoUs: [45.32861664 14.73505632  7.66359245]
# Initial mIoU: 22.575755137246002

# %%
pil_grid([pil(f.byte().cpu().numpy()) for f in preds], 5, margin=1)
# Out:
# <PIL.Image.Image image mode=RGB size=1005x205 at 0x7F8F5D3DF0B8>

# %% [markdown]
# ## Lovász-Softmax training

# %%
m.load_state_dict(init_state_dict)

optimizer = Adam(m.parameters(), lr=0.005)

loss_plot = []
iou_plot = []

for iter in tqdm(range(1000)):
    optimizer.zero_grad()
    out = m(feats)
    out = F.softmax(out)
    loss = L.lovasz_softmax(out, labels, ignore=255)
    loss.backward()
    optimizer.step()
    
    _, preds = out.data.max(1)
    loss_plot.append(loss.item())
    iou_plot.append(L.iou_binary(preds.cpu().numpy(), labels.cpu().numpy(), ignore=255, per_image=False))
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
plt.figure(figsize=(10, 5))
plt.suptitle(u'Lovász-Softmax training')
plt.subplot(1, 2, 1)
plt.plot(loss_plot)
plt.ylabel('loss')
plt.xlabel('iteration')

plt.subplot(1, 2, 2)
plt.plot(iou_plot)
plt.ylabel('Image-IoU (%)')
plt.xlabel('iteration')
# Out:
# Text(0.5,0,'iteration')

# %% [markdown]
# ### Final prediction

# %%
with torch.no_grad():
    _, preds = m(feats).data.max(1)
    print("Final batch-IoUs:", L.iou(preds.cpu().numpy(), labels.cpu().numpy(), C, ignore=255, per_image=False))
    print("Final mIoU:", np.mean(L.iou(preds.cpu().numpy(), labels.cpu().numpy(), C, ignore=255, per_image=False)))
# Out:
# Final batch-IoUs: [87.32373918 43.99441341 30.91196778]
# Final mIoU: 54.07670678874422

# %%
pil_grid([pil(f.byte().cpu().numpy()) for f in preds], 5, margin=1)
# Out:
# <PIL.Image.Image image mode=RGB size=1005x205 at 0x7F8EF53D5940>

# %% [markdown]
# ## Cross-entropy training

# %%
m.load_state_dict(init_state_dict)

optimizer = Adam(m.parameters(), lr=0.005)

loss_plot_x = []
iou_plot_x = []

for iter in tqdm(range(1000)):
    optimizer.zero_grad()
    out = m(feats)
    loss = L.xloss(out, labels, ignore=255)
    loss.backward()
    optimizer.step()
    
    _, preds = out.data.max(1)
    loss_plot_x.append(loss.item())
    iou_plot_x.append(L.iou_binary(preds.cpu().numpy(), labels.cpu().numpy(), ignore=255, per_image=False))
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
plt.figure(figsize=(10, 5))
plt.suptitle(u'Binary cross-entropy training')
plt.subplot(1, 2, 1)
plt.plot(loss_plot_x)
plt.ylabel('loss')
plt.xlabel('iteration')

plt.subplot(1, 2, 2)
plt.plot(iou_plot_x)
plt.ylabel('Image-IoU (%)')
plt.xlabel('iteration')
# Out:
# Text(0.5,0,'iteration')

# %% [markdown]
# ### Final prediction

# %%
with torch.no_grad():
    _, preds = m(feats).data.max(1)
    print("Final batch-IoUs:", L.iou(preds.cpu().numpy(), labels.cpu().numpy(), C, ignore=255, per_image=False))
    print("Final mIoU:", np.mean(L.iou(preds.cpu().numpy(), labels.cpu().numpy(), C, ignore=255, per_image=False)))
# Out:
# Final batch-IoUs: [88.49193506 40.87555537 26.24784854]
# Final mIoU: 51.87177965605216

# %%
pil_grid([pil(f.byte().cpu().numpy()) for f in preds], 5, margin=1)
# Out:
# <PIL.Image.Image image mode=RGB size=1005x205 at 0x7F8EF3785048>
